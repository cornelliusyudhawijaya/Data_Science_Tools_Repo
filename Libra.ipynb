# %% [markdown]
# # This notebook is code to accompany article Create a complex Machine Learning model in one line with Libra
#
# Article: https://towardsdatascience.com/create-a-complex-machine-learning-model-in-one-line-with-libra-a253e05d15a1?sk=65bcf4494dda8b18265e27b5407f44c9
#
# Dataset: https://www.kaggle.com/aljarah/xAPI-Edu-Data

# %%
from libra import client

# %%
edu = pd.read_csv('xAPI-Edu-Data.csv')

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
edu_client = client('xAPI-Edu-Data.csv')
# Out:
# Creating client object
#   |- Reading in dataset

# %%
edu_client.neural_network_query('classify the class')
# Out:
# Reading in dataset
# ->Target column found: Class
#   |- Establishing callback function
#     |- Training initial model
#       | Initial number of layers   | Training Accuracy        | Test Accuracy             |
#       | 3                          | 0.9967426657676697       | 0.7142857313156128        |
#       |- Testing number of layers
#         | Current number of layers  | Training Accuracy       | Test Accuracy            |
#         | 3                         | 0.9967426657676697      | 0.7272727489471436       |
#         | 4                         | 1.0                     | 0.7402597665786743       |
#         | 5                         | 0.9967426657676697      | 0.7142857313156128       |
#
#       ->Best number of layers found: 4
#       ->Training Accuracy: 1.0
#       ->Test Accuracy: 0.7402597665786743
#
#         |- Stored model under 'classification_ANN' key

# %%
edu_client.analyze()
# Out:
# Analyzing classification_ANN for further understanding
#   |- Making predictions for test data
#     |- Transforming dataset for plotting module
#     ->Plotting ROC curves and creating confusion matrix...
#       |- Investigating potential issues with calculations
#         |- Gathering metrics for display:
#         ->Accuracy on test set: 0.7402597665786743
#         ->Recall on test set: 0.7402597402597403
#         ->Precision on test set: 0.7402597402597403
#         ->F1 Score on test set: 0.7402597402597403

# %%
edu_client.decision_tree_query('classify the class')
# Out:
# Reading in dataset
#   |- Preprocessing data
#   ->Target column found: Class
#     |- Labels being mapped to appropriate classes
#       |- Fitting Decision Tree
#       ->Score found on testing set: 0.7402597402597403
#         |- Stored model under 'decision_tree' key
